# %%
import pandas as pd
import os

dataset_rename = {'cw': 'ContentWise', 'rl4rs': 'RL4RS'}

files = [file for file in os.listdir('.') if file.endswith('csv') and file.split('_')[0] in dataset_rename]
model_names = list(set([file.split('_')[-1].split('.')[0] for file in files]))
print('all models', model_names)


# slatewise ,'NeuralClickModelBest',
# model_names = {
#     'MatrixFactorization': 'Матричная факторизация', 
#     'LogReg': 'Логистическая Регрессия', 
#     'NeuralClickModel': 'Session-wise Gated Recurrent Unit', 
#     'InSlateAttention' : 'Slate-wise Transformer'
# }


# sequencewise
model_names = {
    'FlatAttentionClickedOnly': 'Session-wise Clicked-Only Transformer (SCOT)', 
    'InSlateAttentionSequencewiseGRU' : 'Двухэтапная модель Transformer+GRU', 
    'FlattenedGRU':'Session-wise Gated Recurrent Unit (GRU)'
}
# Out:
# all models ['FlatAttentionClickedOnly', 'NeuralClickModel', 'FlatAttentionClickedOnly2LinearLnorm', 'NeuralClickModelBest', 'NeuralClickModelReadoutTestOnly', 'FlattenedGRU', 'SlatewiseGRU', 'NeuralClickModelBase', 'LogReg', 'InSlateAttentionSequencewiseGRU', 'InSlateAttention', 'MatrixFactorization']

# %%
data = {}

dataset_rename = {'cw': 'ContentWise', 'rl4rs': 'RL4RS'}
metrics_rename = {'f1':'F1', 'accuracy': 'Accuracy', 'roc-auc':"ROC-AUC"}
embeddings_rename = {'svd':'SVD', 'neural':"nn.Embeddings", 'explicit':"Explicit"}

index = pd.MultiIndex.from_product(
    [["ContentWise", "RL4RS"], ["ROC-AUC", "F1", "Accuracy"]]
)

columns = pd.MultiIndex.from_product(
    [model_names.values(), ["SVD", "nn.Embeddings", "Explicit"]]
)


df = pd.DataFrame(
    index=index,
    columns=columns,
)
data = df.to_dict()
data
# Out:
# {('Session-wise Clicked-Only Transformer (SCOT)',
#   'SVD'): {('ContentWise', 'ROC-AUC'): nan, ('ContentWise',
#    'F1'): nan, ('ContentWise', 'Accuracy'): nan, ('RL4RS',
#    'ROC-AUC'): nan, ('RL4RS', 'F1'): nan, ('RL4RS', 'Accuracy'): nan},
#  ('Session-wise Clicked-Only Transformer (SCOT)',
#   'nn.Embeddings'): {('ContentWise', 'ROC-AUC'): nan, ('ContentWise',
#    'F1'): nan, ('ContentWise', 'Accuracy'): nan, ('RL4RS',
#    'ROC-AUC'): nan, ('RL4RS', 'F1'): nan, ('RL4RS', 'Accuracy'): nan},
#  ('Session-wise Clicked-Only Transformer (SCOT)',
#   'Explicit'): {('ContentWise', 'ROC-AUC'): nan, ('ContentWise',
#    'F1'): nan, ('ContentWise', 'Accuracy'): nan, ('RL4RS',
#    'ROC-AUC'): nan, ('RL4RS', 'F1'): nan, ('RL4RS', 'Accuracy'): nan},
#  ('Двухэтапная модель Transformer+GRU',
#   'SVD'): {('ContentWise', 'ROC-AUC'): nan, ('ContentWise',
#    'F1'): nan, ('ContentWise', 'Accuracy'): nan, ('RL4RS',
#    'ROC-AUC'): nan, ('RL4RS', 'F1'): nan, ('RL4RS', 'Accuracy'): nan},
#  ('Двухэтапная модель Transformer+GRU',
#   'nn.Embeddings'): {('ContentWise', 'ROC-AUC'): nan, ('ContentWise',
#    'F1'): nan, ('ContentWise', 'Accuracy'): nan, ('RL4RS',
#    'ROC-AUC'): nan, ('RL4RS', 'F1'): nan, ('RL4RS', 'Accuracy'): nan},
#  ('Двухэтапная модель Transformer+GRU',
#   'Explicit'): {('ContentWise', 'ROC-AUC'): nan, ('ContentWise',
#    'F1'): nan, ('ContentWise', 'Accuracy'): nan, ('RL4RS',
#    'ROC-AUC'): nan, ('RL4RS', 'F1'): nan, ('RL4RS', 'Accuracy'): nan},
#  ('Session-wise Gated Recurrent Unit (GRU)',
#   'SVD'): {('ContentWise', 'ROC-AUC'): nan, ('ContentWise',
#    'F1'): nan, ('ContentWise', 'Accuracy'): nan, ('RL4RS',
#    'ROC-AUC'): nan, ('RL4RS', 'F1'): nan, ('RL4RS', 'Accuracy'): nan},
#  ('Session-wise Gated Recurrent Unit (GRU)',
#   'nn.Embeddings'): {('ContentWise', 'ROC-AUC'): nan, ('ContentWise',
#    'F1'): nan, ('ContentWise', 'Accuracy'): nan, ('RL4RS',
#    'ROC-AUC'): nan, ('RL4RS', 'F1'): nan, ('RL4RS', 'Accuracy'): nan},
#  ('Session-wise Gated Recurrent Unit (GRU)',
#   'Explicit'): {('ContentWise', 'ROC-AUC'): nan, ('ContentWise',
#    'F1'): nan, ('ContentWise', 'Accuracy'): nan, ('RL4RS',
#    'ROC-AUC'): nan, ('RL4RS', 'F1'): nan, ('RL4RS', 'Accuracy'): nan}}

# %%
for file in files:
    dataset = dataset_rename[file.split('_')[0]]
    try:
        model = model_names[file.split('_')[-1].split('.')[0]]
    except:
        print(file, 'is unknown model')
        continue
    data_dict = pd.read_csv(file).drop('Unnamed: 0', axis=1).set_index('embeddings').to_dict('index')
    for embedding, m in data_dict.items():
        for metric, score in m.items():
#             print(model, embeddings_rename[embedding], dataset, metrics_rename[metric], score )
            try:
                data[model, embeddings_rename[embedding]][dataset, metrics_rename[metric]] = score
            except:
                pass
# Out:
# rl4rs_LogReg.csv is unknown model
# cw_LogReg.csv is unknown model
# cw_FlatAttentionClickedOnly2LinearLnorm.csv is unknown model
# rl4rs_NeuralClickModelBest.csv is unknown model
# cw_NeuralClickModelBest.csv is unknown model
# cw_SlatewiseGRU.csv is unknown model
# cw_NeuralClickModelReadoutTestOnly.csv is unknown model
# rl4rs_FlatAttentionClickedOnly2LinearLnorm.csv is unknown model
# rl4rs_NeuralClickModelBase.csv is unknown model
# cw_NeuralClickModelBase.csv is unknown model
# rl4rs_MatrixFactorization.csv is unknown model
# cw_InSlateAttention.csv is unknown model
# rl4rs_InSlateAttention.csv is unknown model
# cw_NeuralClickModel.csv is unknown model
# rl4rs_NeuralClickModelReadoutTestOnly.csv is unknown model
# cw_MatrixFactorization.csv is unknown model
# rl4rs_NeuralClickModel.csv is unknown model

# %%
df = pd.DataFrame(
    data,
    index=index,
    columns=columns,
).T.dropna(how='all')
df
# Out:
#                                                            ContentWise  \
#                                                                ROC-AUC
# Session-wise Clicked-Only Transformer (SCOT) SVD              0.722628
#                                              nn.Embeddings    0.712000
#                                              Explicit              NaN
# Двухэтапная модель Transformer+GRU           SVD              0.688890
#                                              nn.Embeddings    0.737799
#                                              Explicit              NaN
# Session-wise Gated Recurrent Unit (GRU)      SVD              0.669131
#                                              nn.Embeddings    0.727529
#                                              Explicit              NaN
#
#                                                                       \
#                                                                   F1
# Session-wise Clicked-Only Transformer (SCOT) SVD            0.308945
#                                              nn.Embeddings  0.284926
#                                              Explicit            NaN
# Двухэтапная модель Transformer+GRU           SVD            0.286763
#                                              nn.Embeddings  0.309336
#                                              Explicit            NaN
# Session-wise Gated Recurrent Unit (GRU)      SVD            0.261849
#                                              nn.Embeddings  0.289546
#                                              Explicit            NaN
#
#                                                                       \
#                                                             Accuracy
# Session-wise Clicked-Only Transformer (SCOT) SVD            0.799244
#                                              nn.Embeddings  0.866837
#                                              Explicit            NaN
# Двухэтапная модель Transformer+GRU           SVD            0.861957
#                                              nn.Embeddings  0.863254
#                                              Explicit            NaN
# Session-wise Gated Recurrent Unit (GRU)      SVD            0.773317
#                                              nn.Embeddings  0.861753
#                                              Explicit            NaN
#
#                                                                RL4RS  \
#                                                              ROC-AUC
# Session-wise Clicked-Only Transformer (SCOT) SVD            0.926009
#                                              nn.Embeddings  0.902031
#                                              Explicit       0.897426
# Двухэтапная модель Transformer+GRU           SVD            0.917050
#                                              nn.Embeddings  0.933702
#                                              Explicit       0.878918
# Session-wise Gated Recurrent Unit (GRU)      SVD            0.922482
#                                              nn.Embeddings  0.920331
#                                              Explicit       0.924105
#
#
#                                                                   F1  Accuracy
# Session-wise Clicked-Only Transformer (SCOT) SVD            0.893666  0.858494
#                                              nn.Embeddings  0.935525  0.869447
#                                              Explicit       0.931149  0.864877
# Двухэтапная модель Transformer+GRU           SVD            0.871182  0.838786
#                                              nn.Embeddings  0.892773  0.859799
#                                              Explicit       0.856078  0.802080
# Session-wise Gated Recurrent Unit (GRU)      SVD            0.884448  0.851094
#                                              nn.Embeddings  0.881862  0.847685
#                                              Explicit       0.885449  0.852352

# %%
df = df.style.format(decimal='.', precision=3).highlight_max(axis=0, props="font-weight:bold;")

# %%
df
# Out:
# <style type="text/css">
# #T_a3409_row1_col2, #T_a3409_row1_col4, #T_a3409_row1_col5, #T_a3409_row4_col0, #T_a3409_row4_col1, #T_a3409_row4_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_a3409">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3409_level0_col0" class="col_heading level0 col0" colspan="3">ContentWise</th>
#       <th id="T_a3409_level0_col3" class="col_heading level0 col3" colspan="3">RL4RS</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_a3409_level1_col0" class="col_heading level1 col0" >ROC-AUC</th>
#       <th id="T_a3409_level1_col1" class="col_heading level1 col1" >F1</th>
#       <th id="T_a3409_level1_col2" class="col_heading level1 col2" >Accuracy</th>
#       <th id="T_a3409_level1_col3" class="col_heading level1 col3" >ROC-AUC</th>
#       <th id="T_a3409_level1_col4" class="col_heading level1 col4" >F1</th>
#       <th id="T_a3409_level1_col5" class="col_heading level1 col5" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3409_level0_row0" class="row_heading level0 row0" rowspan="3">Session-wise Clicked-Only Transformer (SCOT)</th>
#       <th id="T_a3409_level1_row0" class="row_heading level1 row0" >SVD</th>
#       <td id="T_a3409_row0_col0" class="data row0 col0" >0.723</td>
#       <td id="T_a3409_row0_col1" class="data row0 col1" >0.309</td>
#       <td id="T_a3409_row0_col2" class="data row0 col2" >0.799</td>
#       <td id="T_a3409_row0_col3" class="data row0 col3" >0.926</td>
#       <td id="T_a3409_row0_col4" class="data row0 col4" >0.894</td>
#       <td id="T_a3409_row0_col5" class="data row0 col5" >0.858</td>
#     </tr>
#     <tr>
#       <th id="T_a3409_level1_row1" class="row_heading level1 row1" >nn.Embeddings</th>
#       <td id="T_a3409_row1_col0" class="data row1 col0" >0.712</td>
#       <td id="T_a3409_row1_col1" class="data row1 col1" >0.285</td>
#       <td id="T_a3409_row1_col2" class="data row1 col2" >0.867</td>
#       <td id="T_a3409_row1_col3" class="data row1 col3" >0.902</td>
#       <td id="T_a3409_row1_col4" class="data row1 col4" >0.936</td>
#       <td id="T_a3409_row1_col5" class="data row1 col5" >0.869</td>
#     </tr>
#     <tr>
#       <th id="T_a3409_level1_row2" class="row_heading level1 row2" >Explicit</th>
#       <td id="T_a3409_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_a3409_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_a3409_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_a3409_row2_col3" class="data row2 col3" >0.897</td>
#       <td id="T_a3409_row2_col4" class="data row2 col4" >0.931</td>
#       <td id="T_a3409_row2_col5" class="data row2 col5" >0.865</td>
#     </tr>
#     <tr>
#       <th id="T_a3409_level0_row3" class="row_heading level0 row3" rowspan="3">Двухэтапная модель Transformer+GRU</th>
#       <th id="T_a3409_level1_row3" class="row_heading level1 row3" >SVD</th>
#       <td id="T_a3409_row3_col0" class="data row3 col0" >0.689</td>
#       <td id="T_a3409_row3_col1" class="data row3 col1" >0.287</td>
#       <td id="T_a3409_row3_col2" class="data row3 col2" >0.862</td>
#       <td id="T_a3409_row3_col3" class="data row3 col3" >0.917</td>
#       <td id="T_a3409_row3_col4" class="data row3 col4" >0.871</td>
#       <td id="T_a3409_row3_col5" class="data row3 col5" >0.839</td>
#     </tr>
#     <tr>
#       <th id="T_a3409_level1_row4" class="row_heading level1 row4" >nn.Embeddings</th>
#       <td id="T_a3409_row4_col0" class="data row4 col0" >0.738</td>
#       <td id="T_a3409_row4_col1" class="data row4 col1" >0.309</td>
#       <td id="T_a3409_row4_col2" class="data row4 col2" >0.863</td>
#       <td id="T_a3409_row4_col3" class="data row4 col3" >0.934</td>
#       <td id="T_a3409_row4_col4" class="data row4 col4" >0.893</td>
#       <td id="T_a3409_row4_col5" class="data row4 col5" >0.860</td>
#     </tr>
#     <tr>
#       <th id="T_a3409_level1_row5" class="row_heading level1 row5" >Explicit</th>
#       <td id="T_a3409_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_a3409_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_a3409_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_a3409_row5_col3" class="data row5 col3" >0.879</td>
#       <td id="T_a3409_row5_col4" class="data row5 col4" >0.856</td>
#       <td id="T_a3409_row5_col5" class="data row5 col5" >0.802</td>
#     </tr>
#     <tr>
#       <th id="T_a3409_level0_row6" class="row_heading level0 row6" rowspan="3">Session-wise Gated Recurrent Unit (GRU)</th>
#       <th id="T_a3409_level1_row6" class="row_heading level1 row6" >SVD</th>
#       <td id="T_a3409_row6_col0" class="data row6 col0" >0.669</td>
#       <td id="T_a3409_row6_col1" class="data row6 col1" >0.262</td>
#       <td id="T_a3409_row6_col2" class="data row6 col2" >0.773</td>
#       <td id="T_a3409_row6_col3" class="data row6 col3" >0.922</td>
#       <td id="T_a3409_row6_col4" class="data row6 col4" >0.884</td>
#       <td id="T_a3409_row6_col5" class="data row6 col5" >0.851</td>
#     </tr>
#     <tr>
#       <th id="T_a3409_level1_row7" class="row_heading level1 row7" >nn.Embeddings</th>
#       <td id="T_a3409_row7_col0" class="data row7 col0" >0.728</td>
#       <td id="T_a3409_row7_col1" class="data row7 col1" >0.290</td>
#       <td id="T_a3409_row7_col2" class="data row7 col2" >0.862</td>
#       <td id="T_a3409_row7_col3" class="data row7 col3" >0.920</td>
#       <td id="T_a3409_row7_col4" class="data row7 col4" >0.882</td>
#       <td id="T_a3409_row7_col5" class="data row7 col5" >0.848</td>
#     </tr>
#     <tr>
#       <th id="T_a3409_level1_row8" class="row_heading level1 row8" >Explicit</th>
#       <td id="T_a3409_row8_col0" class="data row8 col0" >nan</td>
#       <td id="T_a3409_row8_col1" class="data row8 col1" >nan</td>
#       <td id="T_a3409_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_a3409_row8_col3" class="data row8 col3" >0.924</td>
#       <td id="T_a3409_row8_col4" class="data row8 col4" >0.885</td>
#       <td id="T_a3409_row8_col5" class="data row8 col5" >0.852</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(df.to_latex(convert_css=True))
# Out:
# \begin{tabular}{llrrrrrr}
#  &  & \multicolumn{3}{r}{ContentWise} & \multicolumn{3}{r}{RL4RS} \\
#  &  & ROC-AUC & F1 & Accuracy & ROC-AUC & F1 & Accuracy \\
# \multirow[c]{3}{*}{Session-wise Clicked-Only Transformer (SCOT)} & SVD & 0.723 & 0.309 & 0.799 & 0.926 & 0.894 & 0.858 \\
#  & nn.Embeddings & 0.712 & 0.285 & \bfseries 0.867 & 0.902 & \bfseries 0.936 & \bfseries 0.869 \\
#  & Explicit & nan & nan & nan & 0.897 & 0.931 & 0.865 \\
# \multirow[c]{3}{*}{Двухэтапная модель Transformer+GRU} & SVD & 0.689 & 0.287 & 0.862 & 0.917 & 0.871 & 0.839 \\
#  & nn.Embeddings & \bfseries 0.738 & \bfseries 0.309 & 0.863 & \bfseries 0.934 & 0.893 & 0.860 \\
#  & Explicit & nan & nan & nan & 0.879 & 0.856 & 0.802 \\
# \multirow[c]{3}{*}{Session-wise Gated Recurrent Unit (GRU)} & SVD & 0.669 & 0.262 & 0.773 & 0.922 & 0.884 & 0.851 \\
#  & nn.Embeddings & 0.728 & 0.290 & 0.862 & 0.920 & 0.882 & 0.848 \\
#  & Explicit & nan & nan & nan & 0.924 & 0.885 & 0.852 \\
# \end{tabular}
