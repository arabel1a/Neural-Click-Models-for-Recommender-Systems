# %%
import pandas as pd
import os

# %%
files = [file for file in os.listdir('.') if file.endswith('csv')]
model_names = list(set([file.split('_')[-1].split('.')[0] for file in files]))

data = {}

dataset_rename = {'cw': 'ContentWise', 'rl4rs': 'RL4RS'}
metrics_rename = {'f1':'F1', 'accuracy': 'Accuracy', 'roc-auc':"ROC-AUC"}
embeddings_rename = {'svd':'SVD', 'neural':"nn.Embeddings", 'explicit':"Explicit"}

index = pd.MultiIndex.from_product(
    [["ContentWise", "RL4RS"], ["ROC-AUC", "F1", "Accuracy"]]
)

columns = pd.MultiIndex.from_product(
    [model_names, ["SVD", "nn.Embeddings", "Explicit"]]
)


df = pd.DataFrame(
    index=index,
    columns=columns,
)
data = df.to_dict()
data
# Out:
# {('FlattenedGRU', 'SVD'): {('ContentWise', 'ROC-AUC'): nan,
#   ('ContentWise', 'F1'): nan,
#   ('ContentWise', 'Accuracy'): nan,
#   ('RL4RS', 'ROC-AUC'): nan,
#   ('RL4RS', 'F1'): nan,
#   ('RL4RS', 'Accuracy'): nan},
#  ('FlattenedGRU', 'nn.Embeddings'): {('ContentWise', 'ROC-AUC'): nan,
#   ('ContentWise', 'F1'): nan,
#   ('ContentWise', 'Accuracy'): nan,
#   ('RL4RS', 'ROC-AUC'): nan,
#   ('RL4RS', 'F1'): nan,
#   ('RL4RS', 'Accuracy'): nan},
#  ('FlattenedGRU', 'Explicit'): {('ContentWise', 'ROC-AUC'): nan,
#   ('ContentWise', 'F1'): nan,
#   ('ContentWise', 'Accuracy'): nan,
#   ('RL4RS', 'ROC-AUC'): nan,
#   ('RL4RS', 'F1'): nan,
#   ('RL4RS', 'Accuracy'): nan},
#  ('InSlateAttention', 'SVD'): {('ContentWise', 'ROC-AUC'): nan,
#   ('ContentWise', 'F1'): nan,
#   ('ContentWise', 'Accuracy'): nan,
#   ('RL4RS', 'ROC-AUC'): nan,
#   ('RL4RS', 'F1'): nan,
#   ('RL4RS', 'Accuracy'): nan},
#  ('InSlateAttention', 'nn.Embeddings'): {('ContentWise', 'ROC-AUC'): nan,
#   ('ContentWise', 'F1'): nan,
#   ('ContentWise', 'Accuracy'): nan,
#   ('RL4RS', 'ROC-AUC'): nan,
#   ('RL4RS', 'F1'): nan,
#   ('RL4RS', 'Accuracy'): nan},
#  ('InSlateAttention', 'Explicit'): {('ContentWise', 'ROC-AUC'): nan,
#   ('ContentWise', 'F1'): nan,
#   ('ContentWise', 'Accuracy'): nan,
#   ('RL4RS', 'ROC-AUC'): nan,
#   ('RL4RS', 'F1'): nan,
#   ('RL4RS', 'Accuracy'): nan},
#  ('InSlateAttentionSequencewiseGRU', 'SVD'): {('ContentWise', 'ROC-AUC'): nan,
#   ('ContentWise', 'F1'): nan,
#   ('ContentWise', 'Accuracy'): nan,
#   ('RL4RS', 'ROC-AUC'): nan,
#   ('RL4RS', 'F1'): nan,
#   ('RL4RS', 'Accuracy'): nan},
#  ('InSlateAttentionSequencewiseGRU',
#   'nn.Embeddings'): {('ContentWise', 'ROC-AUC'): nan, ('ContentWise',
#    'F1'): nan, ('ContentWise', 'Accuracy'): nan, ('RL4RS',
#    'ROC-AUC'): nan, ('RL4RS', 'F1'): nan, ('RL4RS', 'Accuracy'): nan},
#  ('InSlateAttentionSequencewiseGRU',
#   'Explicit'): {('ContentWise', 'ROC-AUC'): nan, ('ContentWise',
#    'F1'): nan, ('ContentWise', 'Accuracy'): nan, ('RL4RS',
#    'ROC-AUC'): nan, ('RL4RS', 'F1'): nan, ('RL4RS', 'Accuracy'): nan},
#  ('FlatAttentionClickedOnly', 'SVD'): {('ContentWise', 'ROC-AUC'): nan,
#   ('ContentWise', 'F1'): nan,
#   ('ContentWise', 'Accuracy'): nan,
#   ('RL4RS', 'ROC-AUC'): nan,
#   ('RL4RS', 'F1'): nan,
#   ('RL4RS', 'Accuracy'): nan},
#  ('FlatAttentionClickedOnly',
#   'nn.Embeddings'): {('ContentWise', 'ROC-AUC'): nan, ('ContentWise',
#    'F1'): nan, ('ContentWise', 'Accuracy'): nan, ('RL4RS',
#    'ROC-AUC'): nan, ('RL4RS', 'F1'): nan, ('RL4RS', 'Accuracy'): nan},
#  ('FlatAttentionClickedOnly', 'Explicit'): {('ContentWise', 'ROC-AUC'): nan,
#   ('ContentWise', 'F1'): nan,
#   ('ContentWise', 'Accuracy'): nan,
#   ('RL4RS', 'ROC-AUC'): nan,
#   ('RL4RS', 'F1'): nan,
#   ('RL4RS', 'Accuracy'): nan},
#  ('LogReg', 'SVD'): {('ContentWise', 'ROC-AUC'): nan,
#   ('ContentWise', 'F1'): nan,
#   ('ContentWise', 'Accuracy'): nan,
#   ('RL4RS', 'ROC-AUC'): nan,
#   ('RL4RS', 'F1'): nan,
#   ('RL4RS', 'Accuracy'): nan},
#  ('LogReg', 'nn.Embeddings'): {('ContentWise', 'ROC-AUC'): nan,
#   ('ContentWise', 'F1'): nan,
#   ('ContentWise', 'Accuracy'): nan,
#   ('RL4RS', 'ROC-AUC'): nan,
#   ('RL4RS', 'F1'): nan,
#   ('RL4RS', 'Accuracy'): nan},
#  ('LogReg', 'Explicit'): {('ContentWise', 'ROC-AUC'): nan,
#   ('ContentWise', 'F1'): nan,
#   ('ContentWise', 'Accuracy'): nan,
#   ('RL4RS', 'ROC-AUC'): nan,
#   ('RL4RS', 'F1'): nan,
#   ('RL4RS', 'Accuracy'): nan},
#  ('NeuralClickModelBase', 'SVD'): {('ContentWise', 'ROC-AUC'): nan,
#   ('ContentWise', 'F1'): nan,
#   ('ContentWise', 'Accuracy'): nan,
#   ('RL4RS', 'ROC-AUC'): nan,
#   ('RL4RS', 'F1'): nan,
#   ('RL4RS', 'Accuracy'): nan},
#  ('NeuralClickModelBase', 'nn.Embeddings'): {('ContentWise', 'ROC-AUC'): nan,
#   ('ContentWise', 'F1'): nan,
#   ('ContentWise', 'Accuracy'): nan,
#   ('RL4RS', 'ROC-AUC'): nan,
#   ('RL4RS', 'F1'): nan,
#   ('RL4RS', 'Accuracy'): nan},
#  ('NeuralClickModelBase', 'Explicit'): {('ContentWise', 'ROC-AUC'): nan,
#   ('ContentWise', 'F1'): nan,
#   ('ContentWise', 'Accuracy'): nan,
#   ('RL4RS', 'ROC-AUC'): nan,
#   ('RL4RS', 'F1'): nan,
#   ('RL4RS', 'Accuracy'): nan},
#  ('MatrixFactorization', 'SVD'): {('ContentWise', 'ROC-AUC'): nan,
#   ('ContentWise', 'F1'): nan,
#   ('ContentWise', 'Accuracy'): nan,
#   ('RL4RS', 'ROC-AUC'): nan,
#   ('RL4RS', 'F1'): nan,
#   ('RL4RS', 'Accuracy'): nan},
#  ('MatrixFactorization', 'nn.Embeddings'): {('ContentWise', 'ROC-AUC'): nan,
#   ('ContentWise', 'F1'): nan,
#   ('ContentWise', 'Accuracy'): nan,
#   ('RL4RS', 'ROC-AUC'): nan,
#   ('RL4RS', 'F1'): nan,
#   ('RL4RS', 'Accuracy'): nan},
#  ('MatrixFactorization', 'Explicit'): {('ContentWise', 'ROC-AUC'): nan,
#   ('ContentWise', 'F1'): nan,
#   ('ContentWise', 'Accuracy'): nan,
#   ('RL4RS', 'ROC-AUC'): nan,
#   ('RL4RS', 'F1'): nan,
#   ('RL4RS', 'Accuracy'): nan}}

# %%
for file in files:
    dataset = dataset_rename[file.split('_')[0]]
    model = file.split('_')[-1].split('.')[0]
    data_dict = pd.read_csv(file).drop('Unnamed: 0', axis=1).set_index('embeddings').to_dict('index')
    for embedding, m in data_dict.items():
        for metric, score in m.items():
#             print(model, embeddings_rename[embedding], dataset, metrics_rename[metric], score )
            data[model, embeddings_rename[embedding]][dataset, metrics_rename[metric]] = score

# %%
df = pd.DataFrame(
    data,
    index=index,
    columns=columns,
).T.dropna(how='all')
df
# Out:
#                                               ContentWise                      \
#                                                   ROC-AUC        F1  Accuracy
# FlattenedGRU                    SVD              0.736268  0.293388  0.861640
#                                 nn.Embeddings    0.734139  0.306878  0.767766
#                                 Explicit              NaN       NaN       NaN
# InSlateAttention                SVD              0.749389  0.313946  0.874461
#                                 nn.Embeddings    0.738976  0.323503  0.860084
#                                 Explicit              NaN       NaN       NaN
# InSlateAttentionSequencewiseGRU SVD              0.753003  0.334397  0.827983
#                                 nn.Embeddings    0.750184  0.318957  0.875675
#                                 Explicit              NaN       NaN       NaN
# FlatAttentionClickedOnly        SVD              0.722628  0.308945  0.799244
#                                 nn.Embeddings    0.712000  0.284926  0.866837
#                                 Explicit              NaN       NaN       NaN
# LogReg                          SVD              0.689643  0.241118  0.842561
#                                 nn.Embeddings    0.688562  0.264406  0.793215
#                                 Explicit              NaN       NaN       NaN
# NeuralClickModelBase            SVD              0.803280  0.351244  0.819344
#                                 nn.Embeddings    0.801789  0.353467  0.816843
#                                 Explicit              NaN       NaN       NaN
# MatrixFactorization             SVD              0.653530  0.198183  0.257367
#
#                                                   RL4RS
#                                                 ROC-AUC        F1  Accuracy
# FlattenedGRU                    SVD            0.922482  0.884448  0.851094
#                                 nn.Embeddings  0.920331  0.881862  0.847685
#                                 Explicit       0.924105  0.885449  0.852352
# InSlateAttention                SVD            0.925636  0.884445  0.847540
#                                 nn.Embeddings  0.927064  0.885775  0.848628
#                                 Explicit       0.928539  0.885196  0.849498
# InSlateAttentionSequencewiseGRU SVD            0.782082  0.812068  0.716963
#                                 nn.Embeddings  0.790031  0.812148  0.720300
#                                 Explicit       0.858991  0.846913  0.786507
# FlatAttentionClickedOnly        SVD                 NaN       NaN       NaN
#                                 nn.Embeddings  0.935525  0.902031  0.869447
#                                 Explicit       0.931149  0.897426  0.864877
# LogReg                          SVD            0.912938  0.874831  0.836078
#                                 nn.Embeddings  0.913241  0.874566  0.837359
#                                 Explicit       0.913952  0.876435  0.837021
# NeuralClickModelBase            SVD            0.959533  0.916303  0.891936
#                                 nn.Embeddings  0.961207  0.917997  0.895152
#                                 Explicit       0.960903  0.917598  0.893870
# MatrixFactorization             SVD            0.718950  0.755192  0.653391

# %%
df.style.highlight_max(axis=0, props="font-weight:bold;")#.to_latex(convert_css=True)
# Out:
# <style type="text/css">
# #T_ef9e2_row7_col2, #T_ef9e2_row15_col0, #T_ef9e2_row16_col1, #T_ef9e2_row16_col3, #T_ef9e2_row16_col4, #T_ef9e2_row16_col5 {
#   font-weight: bold;
# }
# </style>
# <table id="T_ef9e2_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="3">ContentWise</th>
#       <th class="col_heading level0 col3" colspan="3">RL4RS</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >ROC-AUC</th>
#       <th class="col_heading level1 col1" >F1</th>
#       <th class="col_heading level1 col2" >Accuracy</th>
#       <th class="col_heading level1 col3" >ROC-AUC</th>
#       <th class="col_heading level1 col4" >F1</th>
#       <th class="col_heading level1 col5" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef9e2_level0_row0" class="row_heading level0 row0" rowspan="3">FlattenedGRU</th>
#       <th id="T_ef9e2_level1_row0" class="row_heading level1 row0" >SVD</th>
#       <td id="T_ef9e2_row0_col0" class="data row0 col0" >0.736268</td>
#       <td id="T_ef9e2_row0_col1" class="data row0 col1" >0.293388</td>
#       <td id="T_ef9e2_row0_col2" class="data row0 col2" >0.861640</td>
#       <td id="T_ef9e2_row0_col3" class="data row0 col3" >0.922482</td>
#       <td id="T_ef9e2_row0_col4" class="data row0 col4" >0.884448</td>
#       <td id="T_ef9e2_row0_col5" class="data row0 col5" >0.851094</td>
#     </tr>
#     <tr>
#       <th id="T_ef9e2_level1_row1" class="row_heading level1 row1" >nn.Embeddings</th>
#       <td id="T_ef9e2_row1_col0" class="data row1 col0" >0.734139</td>
#       <td id="T_ef9e2_row1_col1" class="data row1 col1" >0.306878</td>
#       <td id="T_ef9e2_row1_col2" class="data row1 col2" >0.767766</td>
#       <td id="T_ef9e2_row1_col3" class="data row1 col3" >0.920331</td>
#       <td id="T_ef9e2_row1_col4" class="data row1 col4" >0.881862</td>
#       <td id="T_ef9e2_row1_col5" class="data row1 col5" >0.847685</td>
#     </tr>
#     <tr>
#       <th id="T_ef9e2_level1_row2" class="row_heading level1 row2" >Explicit</th>
#       <td id="T_ef9e2_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_ef9e2_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_ef9e2_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_ef9e2_row2_col3" class="data row2 col3" >0.924105</td>
#       <td id="T_ef9e2_row2_col4" class="data row2 col4" >0.885449</td>
#       <td id="T_ef9e2_row2_col5" class="data row2 col5" >0.852352</td>
#     </tr>
#     <tr>
#       <th id="T_ef9e2_level0_row3" class="row_heading level0 row3" rowspan="3">InSlateAttention</th>
#       <th id="T_ef9e2_level1_row3" class="row_heading level1 row3" >SVD</th>
#       <td id="T_ef9e2_row3_col0" class="data row3 col0" >0.749389</td>
#       <td id="T_ef9e2_row3_col1" class="data row3 col1" >0.313946</td>
#       <td id="T_ef9e2_row3_col2" class="data row3 col2" >0.874461</td>
#       <td id="T_ef9e2_row3_col3" class="data row3 col3" >0.925636</td>
#       <td id="T_ef9e2_row3_col4" class="data row3 col4" >0.884445</td>
#       <td id="T_ef9e2_row3_col5" class="data row3 col5" >0.847540</td>
#     </tr>
#     <tr>
#       <th id="T_ef9e2_level1_row4" class="row_heading level1 row4" >nn.Embeddings</th>
#       <td id="T_ef9e2_row4_col0" class="data row4 col0" >0.738976</td>
#       <td id="T_ef9e2_row4_col1" class="data row4 col1" >0.323503</td>
#       <td id="T_ef9e2_row4_col2" class="data row4 col2" >0.860084</td>
#       <td id="T_ef9e2_row4_col3" class="data row4 col3" >0.927064</td>
#       <td id="T_ef9e2_row4_col4" class="data row4 col4" >0.885775</td>
#       <td id="T_ef9e2_row4_col5" class="data row4 col5" >0.848628</td>
#     </tr>
#     <tr>
#       <th id="T_ef9e2_level1_row5" class="row_heading level1 row5" >Explicit</th>
#       <td id="T_ef9e2_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_ef9e2_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_ef9e2_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_ef9e2_row5_col3" class="data row5 col3" >0.928539</td>
#       <td id="T_ef9e2_row5_col4" class="data row5 col4" >0.885196</td>
#       <td id="T_ef9e2_row5_col5" class="data row5 col5" >0.849498</td>
#     </tr>
#     <tr>
#       <th id="T_ef9e2_level0_row6" class="row_heading level0 row6" rowspan="3">InSlateAttentionSequencewiseGRU</th>
#       <th id="T_ef9e2_level1_row6" class="row_heading level1 row6" >SVD</th>
#       <td id="T_ef9e2_row6_col0" class="data row6 col0" >0.753003</td>
#       <td id="T_ef9e2_row6_col1" class="data row6 col1" >0.334397</td>
#       <td id="T_ef9e2_row6_col2" class="data row6 col2" >0.827983</td>
#       <td id="T_ef9e2_row6_col3" class="data row6 col3" >0.782082</td>
#       <td id="T_ef9e2_row6_col4" class="data row6 col4" >0.812068</td>
#       <td id="T_ef9e2_row6_col5" class="data row6 col5" >0.716963</td>
#     </tr>
#     <tr>
#       <th id="T_ef9e2_level1_row7" class="row_heading level1 row7" >nn.Embeddings</th>
#       <td id="T_ef9e2_row7_col0" class="data row7 col0" >0.750184</td>
#       <td id="T_ef9e2_row7_col1" class="data row7 col1" >0.318957</td>
#       <td id="T_ef9e2_row7_col2" class="data row7 col2" >0.875675</td>
#       <td id="T_ef9e2_row7_col3" class="data row7 col3" >0.790031</td>
#       <td id="T_ef9e2_row7_col4" class="data row7 col4" >0.812148</td>
#       <td id="T_ef9e2_row7_col5" class="data row7 col5" >0.720300</td>
#     </tr>
#     <tr>
#       <th id="T_ef9e2_level1_row8" class="row_heading level1 row8" >Explicit</th>
#       <td id="T_ef9e2_row8_col0" class="data row8 col0" >nan</td>
#       <td id="T_ef9e2_row8_col1" class="data row8 col1" >nan</td>
#       <td id="T_ef9e2_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_ef9e2_row8_col3" class="data row8 col3" >0.858991</td>
#       <td id="T_ef9e2_row8_col4" class="data row8 col4" >0.846913</td>
#       <td id="T_ef9e2_row8_col5" class="data row8 col5" >0.786507</td>
#     </tr>
#     <tr>
#       <th id="T_ef9e2_level0_row9" class="row_heading level0 row9" rowspan="3">FlatAttentionClickedOnly</th>
#       <th id="T_ef9e2_level1_row9" class="row_heading level1 row9" >SVD</th>
#       <td id="T_ef9e2_row9_col0" class="data row9 col0" >0.722628</td>
#       <td id="T_ef9e2_row9_col1" class="data row9 col1" >0.308945</td>
#       <td id="T_ef9e2_row9_col2" class="data row9 col2" >0.799244</td>
#       <td id="T_ef9e2_row9_col3" class="data row9 col3" >nan</td>
#       <td id="T_ef9e2_row9_col4" class="data row9 col4" >nan</td>
#       <td id="T_ef9e2_row9_col5" class="data row9 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ef9e2_level1_row10" class="row_heading level1 row10" >nn.Embeddings</th>
#       <td id="T_ef9e2_row10_col0" class="data row10 col0" >0.712000</td>
#       <td id="T_ef9e2_row10_col1" class="data row10 col1" >0.284926</td>
#       <td id="T_ef9e2_row10_col2" class="data row10 col2" >0.866837</td>
#       <td id="T_ef9e2_row10_col3" class="data row10 col3" >0.935525</td>
#       <td id="T_ef9e2_row10_col4" class="data row10 col4" >0.902031</td>
#       <td id="T_ef9e2_row10_col5" class="data row10 col5" >0.869447</td>
#     </tr>
#     <tr>
#       <th id="T_ef9e2_level1_row11" class="row_heading level1 row11" >Explicit</th>
#       <td id="T_ef9e2_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_ef9e2_row11_col1" class="data row11 col1" >nan</td>
#       <td id="T_ef9e2_row11_col2" class="data row11 col2" >nan</td>
#       <td id="T_ef9e2_row11_col3" class="data row11 col3" >0.931149</td>
#       <td id="T_ef9e2_row11_col4" class="data row11 col4" >0.897426</td>
#       <td id="T_ef9e2_row11_col5" class="data row11 col5" >0.864877</td>
#     </tr>
#     <tr>
#       <th id="T_ef9e2_level0_row12" class="row_heading level0 row12" rowspan="3">LogReg</th>
#       <th id="T_ef9e2_level1_row12" class="row_heading level1 row12" >SVD</th>
#       <td id="T_ef9e2_row12_col0" class="data row12 col0" >0.689643</td>
#       <td id="T_ef9e2_row12_col1" class="data row12 col1" >0.241118</td>
#       <td id="T_ef9e2_row12_col2" class="data row12 col2" >0.842561</td>
